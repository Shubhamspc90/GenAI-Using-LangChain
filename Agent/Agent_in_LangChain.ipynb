# %%
# Step 1: Import required libraries

from langchain_ollama import ChatOllama
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun

import requests
import os
from dotenv import load_dotenv

# %%
# Load environment variables
import os
from dotenv import load_dotenv

load_dotenv()

ollama_api_key = os.getenv("OLLAMA_API_KEY")

print("OLLAMA API KEY FOUND:", bool(ollama_api_key))
# Out:
# OLLAMA API KEY FOUND: True

# %%
# Step 2: Create built-in DuckDuckGo search tool

search_tool = DuckDuckGoSearchRun()

# %%
# Step 4: Import libraries required for weather tool

import requests
from langchain_core.tools import tool


# Create Custom weather tool
@tool
def get_weather_data(city: str) -> str:
    """
    This function fetches the current weather data for a given city.
    """
    url = f'https://api.weatherstack.com/current?access_key=4d1d8ae207a8c845a52df8a67bf3623e&query={city}'

    response = requests.get(url)

    return response.text

# %%
# Step 5: Import libraries required for Ollama model
from langchain_ollama import ChatOllama

# Create Ollama model
llm = ChatOllama(
    model="gpt-oss:20b-cloud",
    base_url="https://ollama.com",
    client_kwargs={
        "headers": {
            "Authorization": f"Bearer {ollama_api_key}"
        }
    },
    temperature=0
)

# %%
# Step 6: Create the agent
# Latest LangChain uses create_agent instead of
# create_react_agent + AgentExecutor

from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=[
        search_tool,
        get_weather_data
    ]
)

# %%
# Step 7: Invoke the agent

response = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": (
                "Find the capital of Goa, "
                "then find its current weather condition."
            )
        }
    ]
})

# %%
# Step 8: Print the final response

print(response["messages"][-1].content)
# Out:
# **Capital of Goa:**
# Panaji (also spelled Panjim)
#
# **Current weather in Panaji (as of the latest available data – July 6 2026):**
#
# - **Condition:** Sunny
# - **Temperature:** 27 °C (≈ 81 °F) – “pleasant”
# - **Humidity:** 76 %
# - **Wind:** 13 km/h (≈ 8 mph)
# - **Atmospheric pressure:** 1012 mb
# - **UV index:** 10.8
# - **Visibility:** 10 km
#
# *(These figures come from the most recent weather snapshot retrieved via a DuckDuckGo search for “Panaji current weather.”)*

# %%
# User → Agent → DuckDuckGo Search → Madhya Pradesh capital → Weather Tool → Weatherstack → Final Answer
