# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search langchain_experimental
# Out:
# Requirement already satisfied: langchain in E:\GenAI-Using-LangChain\venv\Lib\site-packages (1.4.1)
# Requirement already satisfied: langchain-core in E:\GenAI-Using-LangChain\venv\Lib\site-packages (1.6.3)
# Requirement already satisfied: langchain-community in E:\GenAI-Using-LangChain\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic in E:\GenAI-Using-LangChain\venv\Lib\site-packages (2.13.5)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain_experimental in E:\GenAI-Using-LangChain\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (0.12.6)
# Requirement already satisfied: packaging>=23.2.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-core) (0.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from pydantic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from pydantic) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from pydantic) (0.4.4)
# Requirement already satisfied: anyio in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.15.1)
# Requirement already satisfied: certifi in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.20)
# Requirement already satisfied: h11>=0.16 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Collecting websockets<17,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain)
#   Using cached websockets-16.1.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: distro>=1.7.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: httpcore2==2.13.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (0.10.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (2.5.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.25.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.8.0)
# Requirement already satisfied: greenlet>=1 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: click>=8.1.8 in E:\GenAI-Using-LangChain\venv\Lib\site-packages (from duckduckgo-search) (8.5.0)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-2.0.1-cp310-abi3-win_amd64.whl.metadata (4.0 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.1.3-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Using cached websockets-16.1.1-cp312-cp312-win_amd64.whl (180 kB)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading lxml-6.1.3-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 30.0 MB/s  0:00:00
# Downloading primp-2.0.1-cp310-abi3-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ---------------------------------------- 6.4/6.4 MB 32.5 MB/s  0:00:00
# Installing collected packages: websockets, primp, lxml, duckduckgo-search
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 17.1
#
#     Uninstalling websockets-17.1:
#
#       Successfully uninstalled websockets-17.1
#
#    ---------------------------------------- 0/4 [websockets]
#    ---------------------------------------- 0/4 [websockets]
#    ---------------------------------------- 0/4 [websockets]
#    ---------------------------------------- 0/4 [websockets]
#    ---------------------------------------- 0/4 [websockets]
#    ---------- ----------------------------- 1/4 [primp]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    ------------------------------ --------- 3/4 [duckduckgo-search]
#    ---------------------------------------- 4/4 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 lxml-6.1.3 primp-2.0.1 websockets-16.1.1

# %% [markdown]
# **Built-in Tool - DuckDuckGo Search**

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india about today at 11 am ')

print(results)
# Out:
# Check today's top 10 news stories, headline news, breaking news, latest news, politics news, sports news, entertainment news and business news on Times of India Aaj Tak Live TV Newscast: Watch आजतक live tv streaming online and लाइव टीवीnewsflash about breaking news, political news, news debates, sports news, entertainment and movies news, india news, world news and current affairs on Aaj Tak Live TV. Read full articles, watch videos, browse thousands of titles and more on the 'India' topic with Google News. 6 hours ago · Breaking news from India and the World. Top news stories and videos on Politics, Business, Entertainment, Technology, Sports, Health. India News: Get the latest India News, breaking headlines and live updates on politics, economy, crime, policy, society and major national developments. Hindustan Times: Stay updated with Hindustan Times for the top India news, world events, and breaking stories. Get real-time updates on politics, wars, live cricket scores, entertainment... Read full articles, watch videos, browse thousands of titles and more on the 'India' topic with Google News. 6 hours ago · Breaking news from India and the World. Top news stories and videos on Politics, Business, Entertainment, Technology, Sports, Health. India News: Get the latest India News, breaking headlines and live updates on politics, economy, crime, policy, society and major national developments.

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# **Built-in Tool - Shell Tool**

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('ls')

print(results)
# Out:
# Executing command:
#  ls
# tool_in_langChain.ipynb
# E:\GenAI-Using-LangChain\venv\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# **Custom Tools**

# %%
from langchain_core.tools import tool

# %%
# Step 1 - create a function

def multiply(a, b):
    """Multiply two numbers"""
    return a*b

# %%
# Step 2 - add type hints

def multiply(a: int, b:int) -> int:
    """Multiply two numbers"""
    return a*b

# %%
# Step 3 - add tool decorator

@tool
def multiply(a: int, b:int) -> int:
    """Multiply two numbers"""
    return a*b

# %%
result = multiply.invoke({"a":3, "b":5})

# %%
print(result)

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)

# %%
print(multiply.args_schema.model_json_schema())

# %% [markdown]
# **Method 2 - Using StructuredTool**

# %%
from langchain.tools import StructuredTool
from pydantic import BaseModel, Field

# %%
class MultiplyInput(BaseModel):
    a: int = Field(required=True, description="The first number to add")
    b: int = Field(required=True, description="The second number to add")

# %%
def multiply_func(a: int, b: int) -> int:
    return a * b

# %%
multiply_tool = StructuredTool.from_function(
    func=multiply_func,
    name="multiply",
    description="Multiply two numbers",
    args_schema=MultiplyInput
)

# %%
result = multiply_tool.invoke({'a':3, 'b':3})

print(result)
print(multiply_tool.name)
print(multiply_tool.description)
print(multiply_tool.args)

# %% [markdown]
# **Method 3 - Using BaseTool Class**

# %%
from langchain.tools import BaseTool
from typing import Type

# %%
# arg schema using pydantic

class MultiplyInput(BaseModel):
    a: int = Field(required=True, description="The first number to add")
    b: int = Field(required=True, description="The second number to add")

# %%
class MultiplyTool(BaseTool):
    name: str = "multiply"
    description: str = "Multiply two numbers"

    args_schema: Type[BaseModel] = MultiplyInput

    def _run(self, a: int, b: int) -> int:
        return a * b

# %%
multiply_tool = MultiplyTool()

# %%
result = multiply_tool.invoke({'a':3, 'b':3})

print(result)
print(multiply_tool.name)
print(multiply_tool.description)

print(multiply_tool.args)

# %% [markdown]
# **Toolkit**

# %%
from langchain_core.tools import tool

# Custom tools
@tool
def add(a: int, b: int) -> int:
    """Add two numbers"""
    return a + b

@tool
def multiply(a: int, b: int) -> int:
    """Multiply two numbers"""
    return a * b

# %%
class MathToolkit:
    def get_tools(self):
        return [add, multiply]

# %%
toolkit = MathToolkit()
tools = toolkit.get_tools()

for tool in tools:
    print(tool.name, "=>", tool.description)
